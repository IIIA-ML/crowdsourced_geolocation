# %% [markdown]
# # Learning variance annotation functions with multiple annotators

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm, uniform
import cmdstanpy as cmd
import seaborn as sn
from crowdgeoloc.one_d import sample_tokyo_latitudes, generate_annotators, annotate, \
FunctionNormalAnnotatorPopulation, point_average
from scipy.interpolate import CubicSpline

#from crowdgeoloc.module import *

# %%
cmd.install_cmdstan()
# Out:
# Installing CmdStan version: 2.31.0
# Install directory: /home/cerquide/.cmdstan
# CmdStan version 2.31.0 already installed
# True

# %% [markdown]
# ## Create dataset

# %% [markdown]
# ### Create population of annotators

# %%
w = 20
population = FunctionNormalAnnotatorPopulation()
ann_set = population.sample(w)

# %%
allx = np.arange(1000)/1000.
for i, ann in enumerate(ann_set.annotators):
    sigmas = ann.sigma(allx)
    print("Annotator ",i,":", np.sqrt(np.mean(sigmas*sigmas)))
    plt.plot(allx,sigmas)
plt.legend(np.arange(len(ann_set.annotators)))
plt.show()
# Out:
# Annotator  0 : 0.08296089277976117
# Annotator  1 : 0.08909512861352158
# Annotator  2 : 0.11706037502126865
# Annotator  3 : 0.10317747276995946
# Annotator  4 : 0.07887635452867178
# Annotator  5 : 0.08090045046351027
# Annotator  6 : 0.05207348546144106
# Annotator  7 : 0.046465180096659675
# Annotator  8 : 0.029124080153132018
# Annotator  9 : 0.122889934586606
# Annotator  10 : 0.10461479421117852
# Annotator  11 : 0.08944629761205364
# Annotator  12 : 0.05171702073155762
# Annotator  13 : 0.08940066918790758
# Annotator  14 : 0.08652344404011658
# Annotator  15 : 0.11866081948026315
# Annotator  16 : 0.11712502438575281
# Annotator  17 : 0.05986288781942739
# Annotator  18 : 0.10062217692844612
# Annotator  19 : 0.07487742184302351

# %% [markdown]
# ### Create the points, and their annotations

# %%
t = 100000
k = 3
points = uniform.rvs(size=t)

t_A, w_A, ann = ann_set.random_annotation(k, points)

# %%
print(ann)
# Out:
# [ 0.14466892  0.03286987  0.53507617 ...  0.0893975   1.04511542
#  -0.00237946]

# %% [markdown]
# ## Determine positions by computing the average

# %%
_id, mean = point_average(t_A, ann)

# %% [markdown]
# _annotations = annotations.copy()
# point_indexes = _annotations[:,0].copy()
# _annotations = annotations[:,2]
# #print(_annotations)
# _ndx = np.argsort(point_indexes)
# #print(_ndx)
# _id, _pos, g_count  = np.unique(point_indexes[_ndx],
#                                 return_index=True,
#                                 return_counts=True)
# #print(_pos)
# #print(g_count)
# g_sum = np.add.reduceat(_annotations[_ndx], _pos, axis=0)
# g_mean = g_sum / g_count

# %%
plt.plot(points, mean, "b.", alpha=0.05)
plt.show()

# %% [markdown]
# ## Define the function that connect variance points to construct a variance function

# %%
def f(t, kappa, x, y):
    r = len(x)
    tr = np.repeat(t, r)
    tr.shape=(len(t), r)
    #spacing = x[1] - x[0]
    #print(d)
    d = (tr - x) * (tr - x)
    ed = np.exp(-kappa * d)
    s = np.sum(ed, axis=1)
    #print(s)
    res = np.dot(ed, y)/s
    #print(res)
    return res

# %%
k = 7
x = np.arange(k)/(k-1.)
y = np.random.uniform(size=k)*0.2
plt.plot(x,y,"b.")

# %%
n = 1000
allx=np.arange(n)/(n-1.)
plt.plot(x, y, "b.")
spacing = x[1] - x[0]
ka = 5. / (spacing * spacing)
plt.plot(allx,f(allx, ka, x, y))
plt.show()

# %% [markdown]
# ## Learn the variance profiles using Stan

# %%
gp = cmd.CmdStanModel(stan_file='gp-learn-variances-ma.stan')

# %%
a = len(ann)
l = 25
d = {"w":w,
     "a":a,
     "t":t,
     "t_A":t_A + 1,
     "w_A":w_A + 1,
     "ann":ann,
     "l":l
    }
inits = {"y_grid":np.ones((w,l))*0.1}

# %%
s = gp.optimize(data=d, inits=inits, show_console=True, iter=1000000, algorithm='lbfgs', tol_rel_grad=10000.)
# Out:
# 00:12:36 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] method = optimize
# Chain [1] optimize
# Chain [1] algorithm = lbfgs (Default)
# Chain [1] lbfgs
# Chain [1] init_alpha = 0.001 (Default)
# Chain [1] tol_obj = 9.9999999999999998e-13 (Default)
# Chain [1] tol_rel_obj = 10000 (Default)
# Chain [1] tol_grad = 1e-08 (Default)
# Chain [1] tol_rel_grad = 10000
# Chain [1] tol_param = 1e-08 (Default)
# Chain [1] history_size = 5 (Default)
# Chain [1] iter = 1000000
# Chain [1] save_iterations = 0 (Default)
# Chain [1] id = 1 (Default)
# Chain [1] data
# Chain [1] file = /tmp/tmpbh4jer7p/akpyrtvc.json
# Chain [1] init = /tmp/tmpbh4jer7p/dkpvayy2.json
# Chain [1] random
# Chain [1] seed = 37069
# Chain [1] output
# Chain [1] file = /tmp/tmpbh4jer7p/gp-learn-variances-marbtdmiew/gp-learn-variances-ma-20230108001236.csv
# Chain [1] diagnostic_file =  (Default)
# Chain [1] refresh = 100 (Default)
# Chain [1] sig_figs = -1 (Default)
# Chain [1] profile_file = profile.csv (Default)
# Chain [1] num_threads = 1 (Default)
# Chain [1]
# Chain [1] Initial log joint probability = 513633
# Chain [1] Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# Chain [1] 12        549891   3.15973e-05     0.0317805      0.7987      0.7987       14
# 00:12:48 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] Optimization terminated normally:
# Chain [1] Convergence detected: relative gradient magnitude is below tolerance
# Chain [1]

# %% [markdown]
# ## Evaluate the quality

# %% [markdown]
# ### Quality of the consensuses

# %%
kappa = s.stan_variable("kappa")
x = s.stan_variable("x")
plt.plot(np.abs(points-x), np.abs(points-mean), "b.")
print("Better:", np.sum(np.abs(points-x)<np.abs(points-mean)))
print("Worse:", np.sum(np.abs(points-x)>np.abs(points-mean)))
plt.plot([0,0.2],[0,0.2],"r")
plt.show()
plt.plot(points, x, "b.", alpha=0.05)
plt.plot(points, mean, "r.", alpha=0.05)
plt.show()
y_grid = s.stan_variable("y_grid")
#print(y_grid)
print("Average euclidean distance from the points to the mean consensuses:", np.sum((points - mean) **2)/t)
print("Average euclidean distance from the points to the profiled consensuses:", np.sum((points - x) **2)/t)
print("Average absolute distance from the points to the mean consensuses:", np.sum(np.abs(points - mean))/t)
print("Average absolute distance from the points to the profiled consensuses:", np.sum(np.abs(points - x))/t)
# Out:
# Better: 63641
# Worse: 36359
# Average euclidean distance from the points to the mean consensuses: 0.0026173447024371945
# Average euclidean distance from the points to the profiled consensuses: 0.001939677455368634
# Average absolute distance from the points to the mean consensuses: 0.03935596002171821
# Average absolute distance from the points to the profiled consensuses: 0.032469922780775186

# %% [markdown]
# ### Quality of the variance profiles

# %%
gridpoints = np.arange(l) / (l - 1.)

# %%
for i, ann in enumerate(ann_set.annotators):
    sigmas = ann.sigma(allx)
    sigmas_learned = f(allx, kappa, gridpoints, y_grid[i])
    print("Annotator ",i,":", np.sqrt(np.mean(sigmas*sigmas)), np.sqrt(np.mean(sigmas_learned*sigmas_learned)))
    plt.plot(allx, sigmas, "b")
    plt.plot(allx, sigmas_learned, "r")
    plt.show()
#plt.legend(np.arange(w))
# Out:
# Annotator  0 : 0.082931858839728 0.1008948310813314
# Annotator  1 : 0.08912630757827072 0.10611499099305043
# Annotator  2 : 0.11703104674787414 0.1320356266913745
# Annotator  3 : 0.10317942070065879 0.11844132619759978
# Annotator  4 : 0.07886588928092475 0.09646467582750284
# Annotator  5 : 0.08086465117008697 0.0977481458784349
# Annotator  6 : 0.05205580425206316 0.07534091381540384
# Annotator  7 : 0.046490631893094984 0.0709004550132072
# Annotator  8 : 0.029127829168964 0.061899356177991575
# Annotator  9 : 0.12300175550657097 0.13913616860458264
# Annotator  10 : 0.10466816551891149 0.11940395994572649
# Annotator  11 : 0.08949515957250051 0.10626327583155773
# Annotator  12 : 0.05173975981713958 0.07504213944846938
# Annotator  13 : 0.08943863015101182 0.10518586641182766
# Annotator  14 : 0.08658147756809349 0.10447777966364585
# Annotator  15 : 0.11871325443189484 0.1360452811422981
# Annotator  16 : 0.11716709323256552 0.1323493010968711
# Annotator  17 : 0.059893648380136444 0.08179527534551884
# Annotator  18 : 0.1006636648063659 0.11682199839022453
# Annotator  19 : 0.07488213247003588 0.09339014881103319
