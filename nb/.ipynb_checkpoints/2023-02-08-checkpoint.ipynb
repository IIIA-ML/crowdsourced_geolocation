# %% [markdown]
# # Understanding the new code

# %% [markdown]
# ## Implementation of Bayesian OneShot

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm, uniform
import seaborn as sn
import pandas as pd

from crowdgeoloc.one_d import FunctionNormalAnnotatorPopulation, SimpleNormalAnnotatorPopulation

from crowdgeoloc.experiment import ActiveAnnotationContest, mean_location_norm_error, mean_sigma_norm_error

from crowdgeoloc.active import OneShotDirect, OneShotConservative, OneShotConservative2, OneShotIterative, \
    OneShotMean, KShot, OneShotBayesian, OneShotSpatialBayesian
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
n_points = 1000
n_annotators = 200
redundancy = 4

# %%
annotator_population = SimpleNormalAnnotatorPopulation(uniform())  # sigmas ~ uniform between 0 and 1
point_distribution = uniform()
points = point_distribution.rvs(n_points)
ann_set = annotator_population.sample(n_annotators)

exp = ActiveAnnotationContest(points, ann_set, max_total_annotations=n_points*redundancy)

# %%
real_sigmas = np.array([x._sigma for x in ann_set.annotators])
plt.hist(real_sigmas)
plt.title("Real sigmas histogram")
plt.show()

# %%
# from crowdgeoloc.active import random_annotation
# exp.reset()
# random_annotation(exp)

# %%
exp.reset()
mean_consensus = OneShotMean().run(exp)
print("OneShotMean")
print("Average difference between real points and consensus:", np.mean(abs(points - mean_consensus['locations'])), '\n')

exp.reset()
direct_consensus = OneShotDirect().run(exp)
print("OneShotDirect")
print("Average difference between real points and consensus:", np.mean(abs(points - direct_consensus['locations'])),'\n')

exp.reset()
conservative2_consensus = OneShotConservative2().run(exp)
print("OneShotConservative2")
print("Average difference between real points and consensus:", np.mean(abs(points - conservative2_consensus['locations'])), '\n')

exp.reset()
kshot_consensus = KShot().run(exp)
print("KShot")
print("Average difference between real points and consensus:", np.mean(abs(points - kshot_consensus['locations'])), '\n')
# Out:
# OneShotMean
# Average difference between real points and consensus: 0.2061193007371595
#
# OneShotDirect
# Average difference between real points and consensus: 0.13825778891923982
#
# OneShotConservative2
# Average difference between real points and consensus: 0.12511186073614272
#
# KShot
# Average difference between real points and consensus: 0.11565784989621307

# %%
####################################################################################################################

# %%
####################################################################################################################

# %%
from crowdgeoloc.active import OneShotBayesian
import cmdstanpy as cmd

cmd.install_cmdstan()
# Out:
# Installing CmdStan version: 2.31.0
# Install directory: /home/rocco/.cmdstan
# CmdStan version 2.31.0 already installed
# True

# %%
exp.reset()
bayesian_consensus = OneShotBayesian().run(exp)
# Out:
# 11:30:45 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 11:32:43 - cmdstanpy - INFO - CmdStan done processing.
# 11:32:43 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Consider re-running with show_console=True if the above output is unclear!
# 11:32:43 - cmdstanpy - WARNING - Some chains may have failed to converge.
# 	Chain 1 had 25 divergent transitions (2.5%)
# 	Chain 2 had 2 divergent transitions (0.2%)
# 	Chain 3 had 9 divergent transitions (0.9%)
# 	Chain 4 had 2 divergent transitions (0.2%)
# 	Chain 4 had 43 iterations at max treedepth (4.3%)
# 	Use function "diagnose()" to see further information.

# %%
bayesian_consensus.keys()
# Out:
# dict_keys(['locations', 'sigmas', 'stan points'])

# %%
print("OneShotBayesian")
print("Average difference between real points and consensus:", np.mean(abs(points - bayesian_consensus['locations'])))
# Out:
# OneShotBayesian
# Average difference between real points and consensus: 0.12057328481001917

# %%
plt.plot(points, bayesian_consensus['locations'], 'ro', label = "Locations", alpha = 0.2)
plt.plot(points, bayesian_consensus['stan points'], 'go', label = "Stan points", alpha = 0.2)
plt.plot(np.linspace(0,1,1000), np.linspace(0,1,1000))
plt.title("OneShotBayesian: Recovered points vs Real points")
plt.legend()
plt.show()

# plt.plot(points, mean_consensus['locations'], 'bo', label = 'OneShotMean')
# plt.plot(np.linspace(0,1,1000), np.linspace(0,1,1000), 'r')
# plt.title("Recovered points vs Real points")
# plt.legend()
# plt.show()

# %%
# real_sigmas = np.array([x._sigma for x in ann_set.annotators])
# plt.plot(real_sigmas, bayesian_consensus['sigmas'],'ro', label = 'OneShotBayesian')
# plt.plot(np.linspace(0,1,1000), np.linspace(0,1,1000))
# plt.title("Recovered sigmas vs Real sigmas")
# plt.legend()
# plt.show()

# plt.plot(real_sigmas, direct_consensus['sigmas'],'bo', label = "OneShotMean")
# plt.plot(np.linspace(0,1,1000), np.linspace(0,1,1000),'r')
# plt.title("Recovered sigmas vs Real sigmas")
# plt.legend()
# plt.show()

# %%
models = {"mean": OneShotMean(),
          "direct":OneShotDirect(), 
          #"iterative":OneShotIterative(), 
          "conservative2":OneShotConservative2(),
          "bayesian":OneShotBayesian(),
          #"conservative":OneShotConservative(),
          "10shot":KShot()
         }
metrics = {"mean_location_norm_error":mean_location_norm_error,
          "mean_sigma_norm_error":mean_sigma_norm_error}

# %%
def compare(models, exp, metrics, repeats):
    results = []
    for model_name, m in models.items():
        print(model_name)
        result = {"model": model_name}
        for i in range(repeats):
            exp.reset()
            this_run = m.run(exp)
            result["iteration"] = i
            for metric_name, metric in metrics.items():
                result["metric"] = metric_name
                result["value"] = metric(exp, this_run)
                results.append(result.copy())
    return results

# %%
results = compare(models, exp, metrics, 3)
df=pd.DataFrame(results)
df.head()
# Out:
# mean
# direct
# conservative2
# 11:56:23 - cmdstanpy - INFO - CmdStan start processing
# bayesian
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 11:57:32 - cmdstanpy - INFO - CmdStan done processing.
# 11:57:32 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Consider re-running with show_console=True if the above output is unclear!
# 11:57:32 - cmdstanpy - WARNING - Some chains may have failed to converge.
# 	Chain 1 had 3 divergent transitions (0.3%)
# 	Chain 2 had 13 divergent transitions (1.3%)
# 	Chain 3 had 6 divergent transitions (0.6%)
# 	Chain 4 had 2 divergent transitions (0.2%)
# 	Use function "diagnose()" to see further information.
# 11:57:33 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 11:58:39 - cmdstanpy - INFO - CmdStan done processing.
# 11:58:39 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Consider re-running with show_console=True if the above output is unclear!
# 11:58:39 - cmdstanpy - WARNING - Some chains may have failed to converge.
# 	Chain 1 had 13 divergent transitions (1.3%)
# 	Chain 2 had 5 divergent transitions (0.5%)
# 	Chain 3 had 183 divergent transitions (18.3%)
# 	Chain 4 had 5 divergent transitions (0.5%)
# 	Use function "diagnose()" to see further information.
# 11:58:40 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 11:59:48 - cmdstanpy - INFO - CmdStan done processing.
# 11:59:48 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Consider re-running with show_console=True if the above output is unclear!
# 11:59:49 - cmdstanpy - WARNING - Some chains may have failed to converge.
# 	Chain 1 had 2 divergent transitions (0.2%)
# 	Chain 4 had 2 divergent transitions (0.2%)
# 	Use function "diagnose()" to see further information.
# 10shot
#   model  iteration                    metric     value
# 0  mean          0  mean_location_norm_error  0.223482
# 1  mean          0     mean_sigma_norm_error  0.098076
# 2  mean          1  mean_location_norm_error  0.220307
# 3  mean          1     mean_sigma_norm_error  0.098076
# 4  mean          2  mean_location_norm_error  0.217525

# %%
sn.boxplot(data=df[df["metric"]=="mean_location_norm_error"], x="model", y="value")
plt.show()
sn.boxplot(data=df[df["metric"]=="mean_sigma_norm_error"], x="model", y="value")
# Out:
# <AxesSubplot: xlabel='model', ylabel='value'>

# %%
####################################################################################################################

# %%
####################################################################################################################

# %% [markdown]
# ## Space-dependent sigmas, same (constant) OneShots

# %%
# n_points = 1000
# n_annotators = 200
# redundancy = 4

# %%
annotator_population = FunctionNormalAnnotatorPopulation()
#point_distribution = uniform()
#points = point_distribution.rvs(n_points)
ann_set = annotator_population.sample(n_annotators)

exp2 = ActiveAnnotationContest(points, ann_set, max_total_annotations=n_points*redundancy)

# %%
allx = np.arange(1000)/1000.
sigma0 = ann_set.annotators[0].sigma(allx)
plt.plot(allx, sigma0)
plt.title("Ann 0's sigma")
plt.show()

# %%
real_mean_sigmas = np.array([np.mean(x.sigma(allx)) for x in ann_set.annotators])
plt.hist(real_mean_sigmas)
plt.title("Real mean sigmas histogram")
plt.show()

# %%
exp2.reset()
mean_consensus = OneShotMean().run(exp2)
print("OneShotMean")
print("Average difference between real points and consensus:", np.mean(abs(points - mean_consensus['locations'])), '\n')

exp2.reset()
direct_consensus = OneShotDirect().run(exp2)
print("OneShotDirect")
print("Average difference between real points and consensus:", np.mean(abs(points - direct_consensus['locations'])),'\n')

exp2.reset()
conservative2_consensus = OneShotConservative2().run(exp2)
print("OneShotConservative2")
print("Average difference between real points and consensus:", np.mean(abs(points - conservative2_consensus['locations'])), '\n')

exp2.reset()
kshot_consensus = KShot().run(exp2)
print("KShot")
print("Average difference between real points and consensus:", np.mean(abs(points - kshot_consensus['locations'])), '\n')
# Out:
# OneShotMean
# Average difference between real points and consensus: 0.15299010124028625
#
# OneShotDirect
# Average difference between real points and consensus: 0.11405812189228064
#
# OneShotConservative2
# Average difference between real points and consensus: 0.12057618454347754
#
# KShot
# Average difference between real points and consensus: 0.11278013151830361

# %%
exp2.reset()
bayesian_consensus = OneShotBayesian().run(exp2)
# Out:
# 12:02:46 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 12:04:30 - cmdstanpy - INFO - CmdStan done processing.
# 12:04:30 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Consider re-running with show_console=True if the above output is unclear!
# 12:04:30 - cmdstanpy - WARNING - Some chains may have failed to converge.
# 	Chain 1 had 21 divergent transitions (2.1%)
# 	Chain 2 had 8 divergent transitions (0.8%)
# 	Chain 3 had 7 divergent transitions (0.7%)
# 	Use function "diagnose()" to see further information.

# %%
print("OneShotBayesian")
print("Average difference between real points and consensus:", np.mean(abs(points - bayesian_consensus['stan points'])))
# Out:
# OneShotBayesian
# Average difference between real points and consensus: 0.11550526853535537

# %%
allx = np.arange(1000)/1000.
sigma0 = ann_set.annotators[0].sigma(allx)
plt.plot(allx, sigma0)
#plt.plot(allx, [mean_consensus['sigmas'][0]]*len(allx), label = 'OneShotMean')
plt.plot(allx, [direct_consensus['sigmas'][0]]*len(allx), label = 'OneShotDirect')
plt.plot(allx, [conservative2_consensus['sigmas'][0]]*len(allx), label = 'OneShotConservative2')
# plt.plot(allx, [bayesian_consensus['sigmas'][0]]*len(allx), label = 'OneShotBayesian')
plt.plot(allx, [kshot_consensus['sigmas'][0]]*len(allx), label = 'KShot')
plt.plot(allx, [np.mean(ann_set.annotators[0].sigma(allx))]*len(allx), label = 'Function mean')
plt.title("Ann 0's sigma")
plt.legend()
plt.show()

# %%
models = {"mean": OneShotMean(),
          "direct":OneShotDirect(), 
          #"iterative":OneShotIterative(), 
          "conservative2":OneShotConservative2(),
          "bayesian":OneShotBayesian(),
          #"conservative":OneShotConservative(),
          "10shot":KShot()
         }
metrics = {"mean_location_norm_error":mean_location_norm_error,
          "mean_sigma_norm_error":mean_sigma_norm_error}

# %%
results = compare(models, exp, metrics, 3)
df=pd.DataFrame(results)
df.head()
# Out:
# mean
# direct
# conservative2
# 12:04:32 - cmdstanpy - INFO - CmdStan start processing
# bayesian
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 12:05:46 - cmdstanpy - INFO - CmdStan done processing.
# 12:05:46 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Consider re-running with show_console=True if the above output is unclear!
# 12:05:47 - cmdstanpy - WARNING - Some chains may have failed to converge.
# 	Chain 2 had 12 divergent transitions (1.2%)
# 	Chain 3 had 10 divergent transitions (1.0%)
# 	Chain 4 had 1000 divergent transitions (100.0%)
# 	Use function "diagnose()" to see further information.
# 12:05:48 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 12:08:48 - cmdstanpy - INFO - CmdStan done processing.
# 12:08:48 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Consider re-running with show_console=True if the above output is unclear!
# 12:08:49 - cmdstanpy - WARNING - Some chains may have failed to converge.
# 	Chain 1 had 1 divergent transitions (0.1%)
# 	Chain 2 had 4 divergent transitions (0.4%)
# 	Chain 2 had 11 iterations at max treedepth (1.1%)
# 	Chain 3 had 1000 iterations at max treedepth (100.0%)
# 	Chain 4 had 1 divergent transitions (0.1%)
# 	Use function "diagnose()" to see further information.
# 12:08:50 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 12:10:12 - cmdstanpy - INFO - CmdStan done processing.
# 12:10:12 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Consider re-running with show_console=True if the above output is unclear!
# 12:10:12 - cmdstanpy - WARNING - Some chains may have failed to converge.
# 	Chain 1 had 3 divergent transitions (0.3%)
# 	Chain 2 had 21 divergent transitions (2.1%)
# 	Chain 3 had 10 divergent transitions (1.0%)
# 	Chain 4 had 2 divergent transitions (0.2%)
# 	Use function "diagnose()" to see further information.
# 10shot
#   model  iteration                    metric     value
# 0  mean          0  mean_location_norm_error  0.222717
# 1  mean          0     mean_sigma_norm_error  0.098076
# 2  mean          1  mean_location_norm_error  0.234807
# 3  mean          1     mean_sigma_norm_error  0.098076
# 4  mean          2  mean_location_norm_error  0.226956

# %%
sn.boxplot(data=df[df["metric"]=="mean_location_norm_error"], x="model", y="value")
plt.show()
sn.boxplot(data=df[df["metric"]=="mean_sigma_norm_error"], x="model", y="value")
# Out:
# <AxesSubplot: xlabel='model', ylabel='value'>

# %%
####################################################################################################################

# %%
####################################################################################################################

# %% [markdown]
# ## Implementation of OneShots with space-dependent sigmas

# %%
n_points = 10000
n_annotators = 50
redundancy = 5

# %%
annotator_population = FunctionNormalAnnotatorPopulation()
#point_distribution = uniform()
#points = point_distribution.rvs(n_points)
ann_set = annotator_population.sample(n_annotators)

exp2 = ActiveAnnotationContest(points, ann_set, max_total_annotations=n_points*redundancy)

# %%
exp2.reset()
sb_consensus = OneShotSpatialBayesian().run(exp2)
# Out:
# 16:03:08 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] method = optimize
# Chain [1] optimize
# Chain [1] algorithm = lbfgs (Default)
# Chain [1] lbfgs
# Chain [1] init_alpha = 0.001 (Default)
# Chain [1] tol_obj = 9.9999999999999998e-13 (Default)
# Chain [1] tol_rel_obj = 10000 (Default)
# Chain [1] tol_grad = 1e-08 (Default)
# Chain [1] tol_rel_grad = 10000
# Chain [1] tol_param = 1e-08 (Default)
# Chain [1] history_size = 5 (Default)
# Chain [1] iter = 1000000
# Chain [1] save_iterations = 0 (Default)
# Chain [1] id = 1 (Default)
# Chain [1] data
# Chain [1] file = /tmp/tmpjstwvusm/w_96ghg3.json
# Chain [1] init = /tmp/tmpjstwvusm/szwbvz63.json
# Chain [1] random
# Chain [1] seed = 49610
# Chain [1] output
# Chain [1] file = /tmp/tmpjstwvusm/gp-learn-variances-macg8bkung/gp-learn-variances-ma-20230208160308.csv
# Chain [1] diagnostic_file =  (Default)
# Chain [1] refresh = 100 (Default)
# Chain [1] sig_figs = -1 (Default)
# Chain [1] profile_file = profile.csv (Default)
# Chain [1] num_threads = 1 (Default)
# Chain [1]
# Chain [1] Initial log joint probability = -261308
# Chain [1] Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# 16:03:16 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] 19       38577.7   7.46201e-05    0.00130691           1           1       20
# Chain [1] Optimization terminated normally:
# Chain [1] Convergence detected: relative gradient magnitude is below tolerance
# Chain [1]

# %%
allx = np.arange(1000) / 1000.
for i in range(5):
    plt.plot(allx, ann_set.annotators[i].sigma(allx), 'b')
    plt.plot(allx, sb_consensus['sigmas'][i], 'r')
    plt.show()

# %%
plt.plot(points, sb_consensus['locations'], 'ro', alpha = 0.5)
plt.plot(np.linspace(0,1,1000), np.linspace(0,1,1000), 'b')

# %%
####################################################################################################################

# %%
####################################################################################################################

# %% [markdown]
# ### Comparison with space-dependent sigmas between constant OneShots and SpatialBayesian consensus

# %%
n_points = 10000
n_annotators = 50
redundancy = 5

# %%
annotator_population = FunctionNormalAnnotatorPopulation()
#point_distribution = uniform()
#points = point_distribution.rvs(n_points)
ann_set = annotator_population.sample(n_annotators)

exp2 = ActiveAnnotationContest(points, ann_set, max_total_annotations=n_points*redundancy)

# %%
models = {"mean": OneShotMean(),
          "direct":OneShotDirect(), 
          #"iterative":OneShotIterative(), 
          "conservative2":OneShotConservative2(),
          "bayesian":OneShotBayesian(),
          #"conservative":OneShotConservative(),
          "10shot":KShot(),
          "spatialbayesian":OneShotSpatialBayesian()
         }
metrics = {"mean_location_norm_error":mean_location_norm_error}
          #"mean_sigma_norm_error":mean_sigma_norm_error}

# %%
def compare(models, exp, metrics, repeats):
    results = []
    for model_name, m in models.items():
        print(model_name)
        result = {"model": model_name}
        for i in range(repeats):
            exp.reset()
            this_run = m.run(exp)
            result["iteration"] = i
            for metric_name, metric in metrics.items():
                result["metric"] = metric_name
                result["value"] = metric(exp, this_run)
                results.append(result.copy())
    return results

# %%
results = compare(models, exp2, metrics, 3)
df=pd.DataFrame(results)
df.head()
# Out:
# mean
# direct
# conservative2
# bayesian
# 16:03:47 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 16:06:33 - cmdstanpy - INFO - CmdStan done processing.
# 16:06:33 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# 	Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# 	Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# 	Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# 	Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Consider re-running with show_console=True if the above output is unclear!
# 16:06:34 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 16:09:19 - cmdstanpy - INFO - CmdStan done processing.
# 16:09:19 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# 	Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# 	Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# 	Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Consider re-running with show_console=True if the above output is unclear!
# 16:09:21 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 16:12:17 - cmdstanpy - INFO - CmdStan done processing.
# 16:12:17 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# 	Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# 	Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# 	Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# 	Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in '/home/rocco/crowd_geoloc_https/nb/normal.2.stan', line 24, column 8 to column 55)
# Consider re-running with show_console=True if the above output is unclear!
# 10shot
# spatialbayesian
# 16:12:19 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] method = optimize
# Chain [1] optimize
# Chain [1] algorithm = lbfgs (Default)
# Chain [1] lbfgs
# Chain [1] init_alpha = 0.001 (Default)
# Chain [1] tol_obj = 9.9999999999999998e-13 (Default)
# Chain [1] tol_rel_obj = 10000 (Default)
# Chain [1] tol_grad = 1e-08 (Default)
# Chain [1] tol_rel_grad = 10000
# Chain [1] tol_param = 1e-08 (Default)
# Chain [1] history_size = 5 (Default)
# Chain [1] iter = 1000000
# Chain [1] save_iterations = 0 (Default)
# Chain [1] id = 1 (Default)
# Chain [1] data
# Chain [1] file = /tmp/tmpjstwvusm/9as9pr2u.json
# Chain [1] init = /tmp/tmpjstwvusm/sr272opp.json
# Chain [1] random
# Chain [1] seed = 5818
# Chain [1] output
# Chain [1] file = /tmp/tmpjstwvusm/gp-learn-variances-ma8w1rv2eg/gp-learn-variances-ma-20230208161219.csv
# Chain [1] diagnostic_file =  (Default)
# Chain [1] refresh = 100 (Default)
# Chain [1] sig_figs = -1 (Default)
# Chain [1] profile_file = profile.csv (Default)
# Chain [1] num_threads = 1 (Default)
# Chain [1]
# Chain [1] Initial log joint probability = -277004
# Chain [1] Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# 16:12:25 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] 17       35813.6   7.40433e-05    0.00192273           1           1       18
# Chain [1] Optimization terminated normally:
# Chain [1] Convergence detected: relative gradient magnitude is below tolerance
# Chain [1]
# 16:12:25 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] method = optimize
# Chain [1] optimize
# Chain [1] algorithm = lbfgs (Default)
# Chain [1] lbfgs
# Chain [1] init_alpha = 0.001 (Default)
# Chain [1] tol_obj = 9.9999999999999998e-13 (Default)
# Chain [1] tol_rel_obj = 10000 (Default)
# Chain [1] tol_grad = 1e-08 (Default)
# Chain [1] tol_rel_grad = 10000
# Chain [1] tol_param = 1e-08 (Default)
# Chain [1] history_size = 5 (Default)
# Chain [1] iter = 1000000
# Chain [1] save_iterations = 0 (Default)
# Chain [1] id = 1 (Default)
# Chain [1] data
# Chain [1] file = /tmp/tmpjstwvusm/ehd3gilw.json
# Chain [1] init = /tmp/tmpjstwvusm/ps82jcz_.json
# Chain [1] random
# Chain [1] seed = 86488
# Chain [1] output
# Chain [1] file = /tmp/tmpjstwvusm/gp-learn-variances-ma6cimj4nt/gp-learn-variances-ma-20230208161225.csv
# Chain [1] diagnostic_file =  (Default)
# Chain [1] refresh = 100 (Default)
# Chain [1] sig_figs = -1 (Default)
# Chain [1] profile_file = profile.csv (Default)
# Chain [1] num_threads = 1 (Default)
# Chain [1]
# Chain [1] Initial log joint probability = -279041
# Chain [1] Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# 16:12:31 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] 17       35692.5   8.73847e-05    0.00198962           1           1       18
# Chain [1] Optimization terminated normally:
# Chain [1] Convergence detected: relative gradient magnitude is below tolerance
# Chain [1]
# 16:12:32 - cmdstanpy - INFO - Chain [1] start processing
# Chain [1] method = optimize
# Chain [1] optimize
# Chain [1] algorithm = lbfgs (Default)
# Chain [1] lbfgs
# Chain [1] init_alpha = 0.001 (Default)
# Chain [1] tol_obj = 9.9999999999999998e-13 (Default)
# Chain [1] tol_rel_obj = 10000 (Default)
# Chain [1] tol_grad = 1e-08 (Default)
# Chain [1] tol_rel_grad = 10000
# Chain [1] tol_param = 1e-08 (Default)
# Chain [1] history_size = 5 (Default)
# Chain [1] iter = 1000000
# Chain [1] save_iterations = 0 (Default)
# Chain [1] id = 1 (Default)
# Chain [1] data
# Chain [1] file = /tmp/tmpjstwvusm/m55hc5qw.json
# Chain [1] init = /tmp/tmpjstwvusm/up_ud80i.json
# Chain [1] random
# Chain [1] seed = 44742
# Chain [1] output
# Chain [1] file = /tmp/tmpjstwvusm/gp-learn-variances-ma3thvlder/gp-learn-variances-ma-20230208161232.csv
# Chain [1] diagnostic_file =  (Default)
# Chain [1] refresh = 100 (Default)
# Chain [1] sig_figs = -1 (Default)
# Chain [1] profile_file = profile.csv (Default)
# Chain [1] num_threads = 1 (Default)
# Chain [1]
# Chain [1] Initial log joint probability = -271526
# Chain [1] Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# 16:12:38 - cmdstanpy - INFO - Chain [1] done processing
# Chain [1] 19         35799   6.11737e-05    0.00171143           1           1       20
# Chain [1] Optimization terminated normally:
# Chain [1] Convergence detected: relative gradient magnitude is below tolerance
# Chain [1]
#     model  iteration                    metric     value
# 0    mean          0  mean_location_norm_error  0.043213
# 1    mean          1  mean_location_norm_error  0.042779
# 2    mean          2  mean_location_norm_error  0.047036
# 3  direct          0  mean_location_norm_error  0.029808
# 4  direct          1  mean_location_norm_error  0.030643

# %%
sn.boxplot(data=df[df["metric"]=="mean_location_norm_error"], x="model", y="value")
plt.show()
# sn.boxplot(data=df[df["metric"]=="mean_sigma_norm_error"], x="model", y="value")
